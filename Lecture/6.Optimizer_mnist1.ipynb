# %%
# model.compile: 모델을 컴파일
# optimizer: 사용할 옵티마이저를 지정
# loss: 손실 함수를 지정. 여기서는 sparse_categorical_crossentropy를 사용하여 다중 클래스 분류 문제를 해결.
# metrics: 평가 지표를 지정. 여기서는 정확도(accuracy)를 사용.




import tensorflow as tf #딥러닝
from tensorflow import keras #고수준 API, 신경망 모델을 쉽게 구축하고 훈련
import matplotlib.pyplot as plt #데이터 시각화



(train_x, train_y), (test_x, test_y) = keras.datasets.mnist.load_data() # MNIST 손글씨 숫자(0~9) 데이터셋을 로드
x_train = train_x / 255. #입력 데이터를 0과 1 사이의 값으로 정규화 / 학습 속도를 향상시키고 모델의 성능을 개선하는 데 도움이 됨.



# 모델 구조 / model.add =  Keras의 Sequential 모델에 새로운 층(layer)을 추가하는 메서드
model = keras.Sequential() #tf.keras.Sequential: 순차적인 모델을 정의
model.add(keras.layers.Flatten(input_shape=(28, 28, 1))) #tf.keras.layers.Flatten: 2차원 이미지 데이터를 1차원 벡터로 펼칩니다
model.add(keras.layers.Dense(units=64, activation='relu')) #히든레이어1 / tf.keras.layers.Dense: 완전 연결층을 추가 / units: 출력 뉴런의 수를 지정. / activation: 활성화 함수를 지정. 여기서는 ReLU를 사용하여 비선형성을 부여했음.
model.add(keras.layers.Dense(units=64, activation='relu')) #히든레이어2
model.add(keras.layers.Dense(units=10, activation='softmax')) #output 출력층으로, 10개의 클래스(0~9)에 대한 확률을 출력. softmax 활성화 함수를 사용하여 각 클래스에 대한 확률을 계산.



model.summary() #딥러닝 모델의 구조를 요약하여 출력 / 모델층별정보, 총파리미터수, 모델크기 등을 표로 출력해줌



sgd = keras.optimizers.SGD(learning_rate=0.01) # #확률적 경사 하강법(Stochastic Gradient Descent) 옵티마이저를 사용 / sgd는 SGD옵티마이저 학습률 0.01로 지정
model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics=['accuracy']) #지정한 sgd로 model을 컴파일
hist_sgd = model.fit(x_train, train_y, epochs=20, batch_size=32) #컴파일된 model를 fit으로 학습하여 hist_sgd에 넣기


mgd = keras.optimizers.SGD(momentum=0.5, learning_rate=0.01) # Momentum GD
model.compile(optimizer=mgd, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist_mgd = model.fit(x=x_train, y=train_y, epochs=20, batch_size=32)


nes = keras.optimizers.SGD(momentum=0.5, nesterov=True, learning_rate=0.01) # Nestrov Accelerated GD /nesterov 적용할지말지 켜고 끄는 True, False
model.compile(optimizer=nes, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist_nes = model.fit(x=x_train, y=train_y, epochs=20, batch_size=32)



# model.fit: 모델을 학습시킴
# x_train, train_y: 학습 데이터와 레이블을 지정
# epochs: 전체 데이터셋을 몇 번 반복하여 학습할지를 지정.
# batch_size: 한 번에 학습할 데이터의 개수를 지정.



plt.plot(hist_sgd.epoch, hist_sgd.history["loss"], label="SGD")
plt.plot(hist_mgd.epoch, hist_mgd.history["loss"], label="MGD")
plt.plot(hist_nes.epoch, hist_nes.history["loss"], label="Nestrov")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ...
